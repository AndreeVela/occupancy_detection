# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import enum
import os

import sys
# sys.path.append( '/content/drive/My Drive/thesis-workspace' ) # drive version
sys.path.append( '../../../src/' ) # local version

from ml.preprocessing import *

# %% [markdown]
# # Classification

# %% [markdown]
# ## Loading Datasets

# %%
class DF( enum.Enum ):
    _FULL = 1
    _REDUCED_RFE = 2
    _REDUCED_KBEST = 3
    _MIN = 4

# path = [ '.', 'drive', 'My Drive', 'thesis-workspace', 'datasets' ]
path = [ '..', '..', '..', 'datasets', 'feature_selection', 'diff-hum-tem' ]

df = {}
df[ DF._FULL ] = pd.read_csv( os.path.join( *path, 'fs-home-full.csv' ) , index_col = 'date', parse_dates = [ 'date' ] )
df[ DF._REDUCED_RFE ] = pd.read_csv( os.path.join( *path, 'fs-home-rfe.csv' ), index_col = 'date', parse_dates = [ 'date' ] )
df[ DF._REDUCED_KBEST ] = pd.read_csv( os.path.join( *path, 'fs-home-kbest.csv' ), index_col = 'date', parse_dates = [ 'date' ] )
df[ DF._MIN ] = pd.read_csv( os.path.join( *path, 'fs-home-min.csv' ), index_col = 'date', parse_dates = [ 'date' ] )

# %% [markdown]
# ## Data splitting, standarization and balancing

# %%
from imblearn.over_sampling import ADASYN
from collections import Counter


# Number of neighbors to use for balancing each dataset

neighbors = { 
    DF._FULL: 1,
    DF._REDUCED_RFE: 1,
    DF._REDUCED_KBEST: 1,
    DF._MIN: 1
}

for k, d in df.items() :  
    temp = list( split_data( d, test_size = 0.20 ) )
    temp[ X_TRAIN ], temp[ X_TEST ] = standardize( temp[ X_TRAIN ], temp[ X_TEST ] )
    
    print( 'Before balancing:', k, Counter( temp[ Y_TRAIN ] ) )
    temp[ X_TRAIN ], temp[ Y_TRAIN ] = balance_df( 
        temp[ X_TRAIN ], 
        temp[ Y_TRAIN ], 
        neighbors[ k ] )
    print( 'After balancing:', k, Counter( temp[ Y_TRAIN ] ) )
    print()
    
    df[ k ] = temp
# Out:
# Before balancing: DF._FULL Counter({'L': 16301, 'E': 4128, 'M': 2832, 'H': 531})
# After balancing: DF._FULL Counter({'L': 16301, 'H': 16211, 'M': 16092, 'E': 15912})
#
# Before balancing: DF._REDUCED_RFE Counter({'L': 16301, 'E': 4128, 'M': 2832, 'H': 531})
# After balancing: DF._REDUCED_RFE Counter({'L': 16301, 'H': 16284, 'M': 16282, 'E': 16254})
#
# Before balancing: DF._REDUCED_KBEST Counter({'L': 16301, 'E': 4128, 'M': 2832, 'H': 531})
# After balancing: DF._REDUCED_KBEST Counter({'L': 16301, 'H': 16284, 'M': 16282, 'E': 16254})
#
# Before balancing: DF._MIN Counter({'L': 16325, 'E': 4098, 'M': 2830, 'H': 547})
# After balancing: DF._MIN Counter({'E': 16353, 'M': 16330, 'H': 16329, 'L': 16325})

# %% [markdown]
# ## Training

# %%
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.tree import DecisionTreeClassifier
from ml.classification import *

params_dt = [ { 
    'criterion': [ 'gini', 'entropy' ], 
    'max_depth': [ 2, 3, 4, 6, 8, 10, 11, 12 ]
} ]

grids = { DF._FULL: None, DF._REDUCED_RFE: None, DF._REDUCED_KBEST: None, DF._MIN: None }

labels = [ 'E', 'H', 'L', 'M' ]

# exclude = [ DF._REDUCED_RFE, DF._REDUCED_KBEST, DF._MIN ]
exclude = [  ]

# %% [markdown]
# ### Regular

# %%
# %%time
for k, d in df.items():
    if( k not in exclude ):
        print( 'Dataset ', k, len( d ) )
        grids[ k ] = train_and_test( 
                DecisionTreeClassifier(), params_dt, 
                d[ X_TRAIN ], d[ Y_TRAIN ], 
                d[ X_TEST ], d[ Y_TEST ], 
                plot_cmatrix = True, labels = labels )
# Out:
# Dataset  DF._FULL 4
# Best params:  {'criterion': 'gini', 'max_depth': 12}
# Training Accuracy 0.9741653345970909
# Test Accuracy:  0.9583123213985544
# Test ROCauc (OvR): 0.9825103555455224
#
# Detailed Classification Report
#               precision    recall  f1-score   support
#
#            E       0.91      0.96      0.94       998
#            H       0.90      0.95      0.92       156
#            L       0.99      0.96      0.97      4068
#            M       0.89      0.96      0.93       727
#
#     accuracy                           0.96      5949
#    macro avg       0.92      0.96      0.94      5949
# weighted avg       0.96      0.96      0.96      5949
#
#
# Dataset  DF._REDUCED_RFE 4
# Best params:  {'criterion': 'entropy', 'max_depth': 12}
# Training Accuracy 0.9845710219904078
# Test Accuracy:  0.9678937636577576
# Test ROCauc (OvR): 0.985503760468873
#
# Detailed Classification Report
#               precision    recall  f1-score   support
#
#            E       0.94      0.98      0.96       998
#            H       0.94      0.94      0.94       156
#            L       0.99      0.97      0.98      4068
#            M       0.91      0.95      0.93       727
#
#     accuracy                           0.97      5949
#    macro avg       0.94      0.96      0.95      5949
# weighted avg       0.97      0.97      0.97      5949
#
#
# Dataset  DF._REDUCED_KBEST 4
# Best params:  {'criterion': 'entropy', 'max_depth': 12}
# Training Accuracy 0.9844289794833223
# Test Accuracy:  0.9689023365271474
# Test ROCauc (OvR): 0.9866582486984641
#
# Detailed Classification Report
#               precision    recall  f1-score   support
#
#            E       0.94      0.98      0.96       998
#            H       0.95      0.94      0.95       156
#            L       0.99      0.97      0.98      4068
#            M       0.91      0.96      0.93       727
#
#     accuracy                           0.97      5949
#    macro avg       0.95      0.96      0.95      5949
# weighted avg       0.97      0.97      0.97      5949
#
#
# Dataset  DF._MIN 4
# Best params:  {'criterion': 'gini', 'max_depth': 12}
# Training Accuracy 0.9812548985545501
# Test Accuracy:  0.966728280961183
# Test ROCauc (OvR): 0.980574017807778
#
# Detailed Classification Report
#               precision    recall  f1-score   support
#
#            E       0.92      0.98      0.95      1029
#            H       0.89      0.94      0.91       141
#            L       0.99      0.97      0.98      4050
#            M       0.94      0.94      0.94       731
#
#     accuracy                           0.97      5951
#    macro avg       0.93      0.96      0.95      5951
# weighted avg       0.97      0.97      0.97      5951
#
#
# CPU times: user 8.11 s, sys: 533 ms, total: 8.64 s
# Wall time: 1min 7s

# %% [markdown]
# # Evaluation

# %%
from ml.evaluation import *

# %% [markdown]
# ## Learning Curves

# %%
# %%time
temp = [ item for item in df.items() if item[ 0 ] not in exclude ]
plot_learning_curves( temp, grids, 'DT' )
# Out:
# CPU times: user 14.3 s, sys: 560 ms, total: 14.9 s
# Wall time: 2min 21s
